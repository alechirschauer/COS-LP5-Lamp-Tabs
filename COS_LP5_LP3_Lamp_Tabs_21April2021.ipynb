# %%
# import the relevant packages

import calcos
from astropy.io import fits
import glob
import numpy as np

# %%
# set a variable "rawtags" to be all the files in my directory
# with the word "rawtag" in it

rawtags = glob.glob('*_rawtag_*.fits')

# %%
# printing the list of files set by the cell above

#print(rawtags)

# %%
# printing out the whole header of the first file (index [0])

#fits.getheader(rawtags[0])

# %%
# setting the 'RANDSEED' value to some number, here 123456789
# and using a for loop to apply this to every file

#fits.setval(rawtags[0], 'RANDSEED', value=123456789)

for myfile in rawtags:
    fits.setval(myfile, 'RANDSEED', value=123456789)

# %%
# print out the 'RANDSEED' value stipulated above
# in this case, the very last file in rawtags

fits.getval(myfile, 'RANDSEED')
# Out:
# 123456789

# %%
# setting the various fits header parameters to what they need to be
# in order to run things well
# NB, the last four aren't even used, but it might save time later
# when we rul CalCOS on them

for myfile in rawtags:
    fits.setval(myfile, 'FLATCORR', value='OMIT')
    fits.setval(myfile, 'WAVECORR', value='OMIT')
    fits.setval(myfile, 'TRCECORR', value='OMIT')
    fits.setval(myfile, 'ALGNCORR', value='OMIT')
    fits.setval(myfile, 'XTRCTALG', value='BOXCAR')
    fits.setval(myfile, 'X1DCORR', value='PERFORM')
    fits.setval(myfile, 'BACKCORR', value='OMIT')
    fits.setval(myfile, 'FLUXCORR', value='OMIT')
    fits.setval(myfile, 'HELCORR', value='OMIT')

# %%
# reading the fits header information for extension 1
# looking for the keywords in Elaine's 2c

#fits.getheader(rawtags[0], ext=1)

# %%
# here I need to set these lamp flash parameters to match what the observations are doing
# the lamp is on for 30 seconds, then off for a while (depends on the exposure),
# so that it builds up signal without getting the lamp too hot

# the science exposures for G130M are 210 seconds, with 120 seconds of total lamp on time,
# while for G140L the science exposure length is 450 seconds, with 240 seconds of
# total lamp time

# also note that, at the beginning of each Visit, there's a single long exposure to settle
# the OSM, which is 1440 seconds for the two G130M Visits, but 1800 seconds for G140L

# here's an "if" statement that Elaine wrote as an example, which we've modified to fit:

for myfile in rawtags:
    if fits.getval(myfile, 'OPT_ELEM') == 'G130M' and fits.getval(myfile, 'EXPTIME', ext=1) < 220.:
        LMPDUR1 = 30.0
        LMP_ON1 = 0.0
        LMPOFF1 = 30.0
        LMPMED1 = 15.00000
        LMPDUR2 = 30.0
        LMP_ON2 = 60.0
        LMPOFF2 = 90.0
        LMPMED2 = 75.00000
        fits.setval(myfile, 'LMPDUR1', value=LMPDUR1, ext=1)
        fits.setval(myfile, 'LMP_ON1', value=LMP_ON1, ext=1)
        fits.setval(myfile, 'LMPOFF1', value=LMPOFF1, ext=1)
        fits.setval(myfile, 'LMPMED1', value=LMPMED1, ext=1)
        fits.setval(myfile, 'LMPDUR2', value=LMPDUR2, ext=1)
        fits.setval(myfile, 'LMP_ON2', value=LMP_ON2, ext=1)
        fits.setval(myfile, 'LMPOFF2', value=LMPOFF2, ext=1)
        fits.setval(myfile, 'LMPMED2', value=LMPMED2, ext=1)
        fits.setval(myfile, 'NUMFLASH', value=4, ext=1)
        fits.setval(myfile, 'TAGFLASH', value='UNIFORMLY SPACED', ext=0)
    elif fits.getval(myfile, 'OPT_ELEM') == 'G130M' and fits.getval(myfile, 'EXPTIME', ext=1) > 220.:
        LMPDUR1 = 30.0
        LMP_ON1 = 0.0
        LMPOFF1 = 30.0
        LMPMED1 = 15.00000
        LMPDUR2 = 30.0
        LMP_ON2 = 120.0
        LMPOFF2 = 150.0
        LMPMED2 = 135.00000
        fits.setval(myfile, 'LMPDUR1', value=LMPDUR1, ext=1)
        fits.setval(myfile, 'LMP_ON1', value=LMP_ON1, ext=1)
        fits.setval(myfile, 'LMPOFF1', value=LMPOFF1, ext=1)
        fits.setval(myfile, 'LMPMED1', value=LMPMED1, ext=1)
        fits.setval(myfile, 'LMPDUR2', value=LMPDUR2, ext=1)
        fits.setval(myfile, 'LMP_ON2', value=LMP_ON2, ext=1)
        fits.setval(myfile, 'LMPOFF2', value=LMPOFF2, ext=1)
        fits.setval(myfile, 'LMPMED2', value=LMPMED2, ext=1)
        fits.setval(myfile, 'NUMFLASH', value=12, ext=1)
        fits.setval(myfile, 'TAGFLASH', value='UNIFORMLY SPACED', ext=0)
    elif fits.getval(myfile, 'OPT_ELEM') == 'G140L' and fits.getval(myfile, 'EXPTIME', ext=1) < 460.:
        LMPDUR1 = 30.0
        LMP_ON1 = 0.0
        LMPOFF1 = 30.0
        LMPMED1 = 15.00000
        LMPDUR2 = 30.0
        LMP_ON2 = 60.0
        LMPOFF2 = 90.0
        LMPMED2 = 75.00000
        fits.setval(myfile, 'LMPDUR1', value=LMPDUR1, ext=1)
        fits.setval(myfile, 'LMP_ON1', value=LMP_ON1, ext=1)
        fits.setval(myfile, 'LMPOFF1', value=LMPOFF1, ext=1)
        fits.setval(myfile, 'LMPMED1', value=LMPMED1, ext=1)
        fits.setval(myfile, 'LMPDUR2', value=LMPDUR2, ext=1)
        fits.setval(myfile, 'LMP_ON2', value=LMP_ON2, ext=1)
        fits.setval(myfile, 'LMPOFF2', value=LMPOFF2, ext=1)
        fits.setval(myfile, 'LMPMED2', value=LMPMED2, ext=1)
        fits.setval(myfile, 'NUMFLASH', value=8, ext=1)
        fits.setval(myfile, 'TAGFLASH', value='UNIFORMLY SPACED', ext=0)
    elif fits.getval(myfile, 'OPT_ELEM') == 'G140L' and fits.getval(myfile, 'EXPTIME', ext=1) > 460.:
        LMPDUR1 = 30.0
        LMP_ON1 = 0.0
        LMPOFF1 = 30.0
        LMPMED1 = 15.00000
        LMPDUR2 = 30.0
        LMP_ON2 = 120.0
        LMPOFF2 = 150.0
        LMPMED2 = 135.00000
        fits.setval(myfile, 'LMPDUR1', value=LMPDUR1, ext=1)
        fits.setval(myfile, 'LMP_ON1', value=LMP_ON1, ext=1)
        fits.setval(myfile, 'LMPOFF1', value=LMPOFF1, ext=1)
        fits.setval(myfile, 'LMPMED1', value=LMPMED1, ext=1)
        fits.setval(myfile, 'LMPDUR2', value=LMPDUR2, ext=1)
        fits.setval(myfile, 'LMP_ON2', value=LMP_ON2, ext=1)
        fits.setval(myfile, 'LMPOFF2', value=LMPOFF2, ext=1)
        fits.setval(myfile, 'LMPMED2', value=LMPMED2, ext=1)
        fits.setval(myfile, 'NUMFLASH', value=15, ext=1)
        fits.setval(myfile, 'TAGFLASH', value='UNIFORMLY SPACED', ext=0)

# %%
# run CalCOS!!!

# let's glob only rawtag_a files because CalCOS has a weird thing about automatically
# processing rawtag_b files, then crashing when it sees a rawtag_b file

rawtagsa = glob.glob('*_rawtag_a.fits')

# now I'm actually going to run CalCOS on my data, outputting to
# the new output directory I made specified by "outdir"

for myfile in rawtagsa:
    calcos.calcos(myfile, outdir='/Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output2')

# ^ the above is commented out so I don't accidentally run CalCOS again,
# since it takes like 20 minutes
# (unless you have to)
# Out:
# CALCOS version 3.3.10
# numpy version 1.19.2
# astropy version 4.2.1
# Begin 21-Apr-2021 15:13:07 EDT
# Input file = leih01ehq_rawtag_a.fits
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih01ehq_rawtag_a.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih01ehq_rawtag_b.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
#
# TIME-TAG calibration -- 21-Apr-2021 15:13:10 EDT
# Input     leih01ehq_rawtag_a.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01ehq_corrtag_a.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01ehq_flt_a.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01ehq_counts_a.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01ehq_lampflash_a.fits
# DETECTOR  FUV, segment A
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1291, FPOFFSET 0
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# Last time interval is short (0.0640166 s), so previous livetime will be used.
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.5  30.5  30.0  15.8
# 2:  121.5  150.5  29.0  136.2
# 3:  241.5  270.5  29.0  256.2
# 4:  361.7  390.5  28.8  376.4
# 5:  481.5  510.5  29.0  496.4
# 6:  601.7  630.5  28.8  616.3
# 7:  721.7  750.5  28.8  736.1
# 8:  841.7  870.5  28.8  856.2
# 9:  961.5  990.5  29.0  975.9
# 10:  1081.7  1110.5  28.8  1096.3
# 11:  1201.5  1230.5  29.0  1216.5
# 12:  1321.5  1350.5  29.0  1336.5
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVA      59.1 (651.0)      65.0 1.01 [ 65.0]    0.0  9784.4 (3942)
#  2 FUVA      59.2 (651.1)      65.0 0.92 [ 65.0]    0.0  10310.0 (3941)
#  3 FUVA      59.3 (651.2)      64.9 0.69 [ 64.9]    0.0  9819.3 (3939)
#  4 FUVA      59.2 (651.1)      65.0 0.97 [ 65.0]    0.0  10426.7 (3979)
#  5 FUVA      59.3 (651.2)      64.9 0.92 [ 64.9]    0.0  9739.0 (3930)
#  6 FUVA      59.2 (651.1)      65.2 0.60 [ 65.2]    0.0  9973.3 (3943)
#  7 FUVA      59.3 (651.2)      65.0 0.73 [ 65.0]    0.0  9771.6 (3927)
#  8 FUVA      59.3 (651.2)      64.8 0.42 [ 64.8]    0.0  9657.6 (3958)
#  9 FUVA      59.4 (651.3)      65.0 1.04 [ 65.0]    0.0  9497.1 (3932)
# 10 FUVA      59.4 (651.3)      64.8 0.39 [ 64.8]    0.0  9756.3 (3942)
# 11 FUVA      59.3 (651.2)      65.2 1.11 [ 65.2]    0.0  10160.2 (3967)
# 12 FUVA      59.3 (651.2)      64.9 1.06 [ 64.9]    0.0  9484.5 (3922)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
#
# TIME-TAG calibration -- 21-Apr-2021 15:13:57 EDT
# Input     leih01ehq_rawtag_b.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01ehq_corrtag_b.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01ehq_flt_b.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01ehq_counts_b.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01ehq_lampflash_b.fits
# DETECTOR  FUV, segment B
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1291, FPOFFSET 0
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# Last time interval is short (0.095999 s), so previous livetime will be used.
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.7  30.5  29.8  16.4
# 2:  121.7  150.5  28.8  136.1
# 3:  241.5  270.7  29.2  255.6
# 4:  361.5  390.5  29.0  376.5
# 5:  481.5  510.5  29.0  496.2
# 6:  601.7  630.5  28.8  616.5
# 7:  721.7  750.5  28.8  736.2
# 8:  841.5  870.5  29.0  856.0
# 9:  961.7  990.5  28.8  975.6
# 10:  1081.7  1110.5  28.8  1096.7
# 11:  1201.7  1230.5  28.8  1216.1
# 12:  1321.5  1350.5  29.0  1336.1
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVB      61.1 (709.3)      59.3 1.50 [ 59.3]    0.0  5431.1 (2552)
#  2 FUVB      61.1 (709.4)      59.8 1.76 [ 59.8]    0.0  5614.0 (2554)
#  3 FUVB      61.2 (709.5)      59.6 1.31 [ 59.6]    0.0  5695.5 (2546)
#  4 FUVB      61.2 (709.4)      60.2 2.97 [ 60.2]    0.0  5439.4 (2556)
#  5 FUVB      61.1 (709.4)      59.6 1.28 [ 59.6]    0.0  5668.8 (2537)
#  6 FUVB      61.1 (709.4)      60.2 3.73 [ 60.2]    0.0  5841.5 (2534)
#  7 FUVB      61.1 (709.4)      59.9 1.03 [ 59.9]    0.0  5525.1 (2515)
#  8 FUVB      61.3 (709.6)      59.8 1.28 [ 59.8]    0.0  5811.6 (2543)
#  9 FUVB      61.3 (709.6)      60.4 1.96 [ 60.4]    0.0  5465.2 (2495)
# 10 FUVB      61.2 (709.5)      59.9 0.99 [ 59.9]    0.0  5584.4 (2508)
# 11 FUVB      61.0 (709.3)      59.9 0.36 [ 59.9]    0.0  5555.2 (2533)
# 12 FUVB      61.0 (709.3)      59.9 1.47 [ 59.9]    0.0  5838.2 (2561)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
# Warning:  SPWCSTAB = N/A, so WCS keywords will not be updated
# End   21-Apr-2021 15:14:49 EDT
# CALCOS version 3.3.10
# numpy version 1.19.2
# astropy version 4.2.1
# Begin 21-Apr-2021 15:14:49 EDT
# Input file = leih01g5q_rawtag_a.fits
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih01g5q_rawtag_a.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih01g5q_rawtag_b.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
#
# TIME-TAG calibration -- 21-Apr-2021 15:14:50 EDT
# Input     leih01g5q_rawtag_a.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01g5q_corrtag_a.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01g5q_flt_a.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01g5q_counts_a.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01g5q_lampflash_a.fits
# DETECTOR  FUV, segment A
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1300, FPOFFSET 0
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.7  30.7  30.0  15.3
# 2:  60.7  90.5  29.8  75.7
# 3:  120.7  150.7  30.0  135.5
# 4:  180.7  210.0  29.4  195.1
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVA      59.1 (650.4)      34.8 0.52 [ 34.8]    0.0  9464.1 (4092)
#  2 FUVA      59.0 (650.3)      34.2 0.54 [ 34.2]    0.0  9797.2 (4097)
#  3 FUVA      59.1 (650.4)      34.0 0.53 [ 34.0]    0.0  9552.6 (4083)
#  4 FUVA      59.0 (650.4)      33.6 0.77 [ 33.6]    0.0  9301.6 (4082)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
#
# TIME-TAG calibration -- 21-Apr-2021 15:15:13 EDT
# Input     leih01g5q_rawtag_b.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01g5q_corrtag_b.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01g5q_flt_b.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01g5q_counts_b.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01g5q_lampflash_b.fits
# DETECTOR  FUV, segment B
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1300, FPOFFSET 0
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.6  30.6  30.0  15.5
# 2:  60.6  90.6  30.0  75.6
# 3:  120.6  150.4  29.8  135.7
# 4:  180.6  210.0  29.4  195.6
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVB      61.8 (708.7)      31.3 0.58 [ 31.3]    0.0  5909.7 (2830)
#  2 FUVB      62.0 (708.8)      30.6 1.14 [ 30.6]    0.0  5739.1 (2740)
#  3 FUVB      62.0 (708.9)      30.3 1.09 [ 30.3]    0.0  5549.5 (2810)
#  4 FUVB      62.0 (708.8)      30.1 0.64 [ 30.1]    0.0  5805.9 (2831)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
# Warning:  SPWCSTAB = N/A, so WCS keywords will not be updated
# End   21-Apr-2021 15:15:34 EDT
# CALCOS version 3.3.10
# numpy version 1.19.2
# astropy version 4.2.1
# Begin 21-Apr-2021 15:15:34 EDT
# Input file = leih02c6q_rawtag_a.fits
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih02c6q_rawtag_a.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih02c6q_rawtag_b.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
#
# TIME-TAG calibration -- 21-Apr-2021 15:15:35 EDT
# Input     leih02c6q_rawtag_a.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c6q_corrtag_a.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c6q_flt_a.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c6q_counts_a.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c6q_lampflash_a.fits
# DETECTOR  FUV, segment A
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1318, FPOFFSET 1
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.6  30.6  30.0  15.8
# 2:  60.6  90.6  30.0  75.8
# 3:  120.6  150.6  30.0  135.8
# 4:  180.6  210.0  29.4  195.8
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVA      58.9 (649.3)     361.6 0.13 [ 69.8]  291.8  9148.8 (3996)
#  2 FUVA      58.9 (649.3)     361.4 0.55 [ 69.6]  291.8  8616.4 (4007)
#  3 FUVA      58.9 (649.4)     361.3 0.55 [ 69.5]  291.8  9183.8 (4030)
#  4 FUVA      59.1 (649.6)     361.5 0.61 [ 69.8]  291.8  8733.8 (4027)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
#
# TIME-TAG calibration -- 21-Apr-2021 15:15:55 EDT
# Input     leih02c6q_rawtag_b.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c6q_corrtag_b.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c6q_flt_b.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c6q_counts_b.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c6q_lampflash_b.fits
# DETECTOR  FUV, segment B
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1318, FPOFFSET 1
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.6  30.6  30.0  15.8
# 2:  60.6  90.6  30.0  75.7
# 3:  120.6  150.4  29.8  135.3
# 4:  180.6  210.0  29.4  195.6
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVB      61.1 (707.8)     359.7 0.49 [ 68.2]  291.5  6406.0 (3148)
#  2 FUVB      61.1 (707.9)     359.4 0.72 [ 67.9]  291.5  6229.3 (3187)
#  3 FUVB      61.2 (707.9)     359.2 0.49 [ 67.7]  291.5  6279.1 (3178)
#  4 FUVB      61.0 (707.7)     359.3 0.80 [ 67.8]  291.5  6440.6 (3176)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
# Warning:  SPWCSTAB = N/A, so WCS keywords will not be updated
# End   21-Apr-2021 15:16:16 EDT
# CALCOS version 3.3.10
# numpy version 1.19.2
# astropy version 4.2.1
# Begin 21-Apr-2021 15:16:16 EDT
# Input file = leih03iiq_rawtag_a.fits
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih03iiq_rawtag_a.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
#
# TIME-TAG calibration -- 21-Apr-2021 15:16:17 EDT
# Input     leih03iiq_rawtag_a.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih03iiq_corrtag_a.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih03iiq_flt_a.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih03iiq_counts_a.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih03iiq_lampflash_a.fits
# DETECTOR  FUV, segment A
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G140L, CENWAVE 800, FPOFFSET -2
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$52j2110ml_lamp.fits
# XTRACTAB= lref$52j2110kl_1dx.fits
# DISPTAB = lref$52j2117ml_disp.fits
# lamp on, off, duration, median time:
# 1:  0.7  30.7  30.0  15.8
# 2:  60.7  90.7  30.0  75.8
# 3:  121.7  150.7  29.0  136.5
# 4:  180.7  210.7  30.0  195.7
# 5:  241.7  270.7  29.0  256.4
# 6:  300.7  330.7  30.0  315.6
# 7:  360.7  390.7  30.0  375.6
# 8:  420.7  450.0  29.4  435.3
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVA       0.1 (564.4)    -517.4 0.00 [  0.0] -517.4     0.0 (0)  # not found
#  2 FUVA       0.2 (564.5)    -517.4 0.00 [  0.0] -517.4     0.0 (0)  # not found
#  3 FUVA       0.3 (564.6)    -517.4 0.00 [  0.0] -517.4     0.0 (0)  # not found
#  4 FUVA       0.4 (564.7)    -517.4 0.00 [  0.0] -517.4     0.0 (0)  # not found
#  5 FUVA       0.4 (564.7)    -517.4 0.00 [  0.0] -517.4     0.0 (0)  # not found
#  6 FUVA       0.3 (564.6)    -517.4 0.00 [  0.0] -517.4     0.0 (0)  # not found
#  7 FUVA       0.4 (564.7)    -517.4 0.00 [  0.0] -517.4     0.0 (0)  # not found
#  8 FUVA       0.3 (564.6)    -517.4 0.00 [  0.0] -517.4     0.0 (0)  # not found
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
# Warning:  SPWCSTAB = N/A, so WCS keywords will not be updated
# End   21-Apr-2021 15:16:47 EDT
# CALCOS version 3.3.10
# numpy version 1.19.2
# astropy version 4.2.1
# Begin 21-Apr-2021 15:16:47 EDT
# Input file = leih01g2q_rawtag_a.fits
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih01g2q_rawtag_a.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih01g2q_rawtag_b.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
#
# TIME-TAG calibration -- 21-Apr-2021 15:16:48 EDT
# Input     leih01g2q_rawtag_a.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01g2q_corrtag_a.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01g2q_flt_a.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01g2q_counts_a.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01g2q_lampflash_a.fits
# DETECTOR  FUV, segment A
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1300, FPOFFSET -1
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.7  30.7  30.0  16.1
# 2:  60.7  90.5  29.8  76.2
# 3:  120.7  150.7  30.0  136.1
# 4:  180.7  210.0  29.4  195.6
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVA      59.0 (650.3)    -100.8 0.75 [132.6] -233.4  9552.1 (4022)
#  2 FUVA      59.1 (650.4)    -101.1 0.34 [132.2] -233.4  9411.7 (4026)
#  3 FUVA      59.2 (650.5)    -101.2 0.42 [132.1] -233.4  9236.2 (4026)
#  4 FUVA      59.1 (650.4)    -101.2 0.38 [132.2] -233.4  9348.2 (4011)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
#
# TIME-TAG calibration -- 21-Apr-2021 15:17:09 EDT
# Input     leih01g2q_rawtag_b.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01g2q_corrtag_b.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01g2q_flt_b.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01g2q_counts_b.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01g2q_lampflash_b.fits
# DETECTOR  FUV, segment B
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1300, FPOFFSET -1
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.7  30.7  30.0  15.1
# 2:  60.7  90.5  29.8  75.8
# 3:  120.7  150.5  29.8  135.1
# 4:  180.7  209.9  29.2  195.3
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVB      61.9 (708.8)    -103.8 0.71 [129.0] -232.9  5948.8 (2848)
#  2 FUVB      61.9 (708.7)    -104.0 0.32 [128.8] -232.9  5822.1 (2862)
#  3 FUVB      62.1 (708.9)    -104.5 0.91 [128.4] -232.9  6003.1 (2843)
#  4 FUVB      62.0 (708.9)    -104.4 0.99 [128.5] -232.9  5881.2 (2841)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
# Warning:  SPWCSTAB = N/A, so WCS keywords will not be updated
# End   21-Apr-2021 15:17:31 EDT
# CALCOS version 3.3.10
# numpy version 1.19.2
# astropy version 4.2.1
# Begin 21-Apr-2021 15:17:31 EDT
# Input file = leih02c0q_rawtag_a.fits
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih02c0q_rawtag_a.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih02c0q_rawtag_b.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
#
# TIME-TAG calibration -- 21-Apr-2021 15:17:31 EDT
# Input     leih02c0q_rawtag_a.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c0q_corrtag_a.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c0q_flt_a.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c0q_counts_a.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c0q_lampflash_a.fits
# DETECTOR  FUV, segment A
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1318, FPOFFSET -2
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.5  30.5  30.0  15.6
# 2:  60.5  90.5  30.0  76.2
# 3:  120.5  150.5  30.0  135.5
# 4:  180.5  210.0  29.5  195.6
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVA      58.7 (649.2)    -380.7 0.44 [105.6] -486.3  9442.8 (4244)
#  2 FUVA      58.7 (649.2)    -381.3 0.88 [105.0] -486.3  9382.3 (4274)
#  3 FUVA      58.8 (649.3)    -381.4 0.77 [104.9] -486.3  9291.3 (4259)
#  4 FUVA      58.8 (649.2)    -381.4 0.79 [104.9] -486.3  8864.5 (4278)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
#
# TIME-TAG calibration -- 21-Apr-2021 15:17:50 EDT
# Input     leih02c0q_rawtag_b.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c0q_corrtag_b.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c0q_flt_b.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c0q_counts_b.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c0q_lampflash_b.fits
# DETECTOR  FUV, segment B
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1318, FPOFFSET -2
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.7  30.7  30.0  15.7
# 2:  60.7  90.7  30.0  75.7
# 3:  120.7  150.7  30.0  135.6
# 4:  180.7  210.0  29.4  195.3
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVB      61.3 (708.0)    -385.5 0.80 [105.0] -490.5  9060.2 (3455)
#  2 FUVB      61.2 (707.9)    -385.9 0.57 [104.6] -490.5  9175.1 (3479)
#  3 FUVB      61.2 (707.9)    -386.2 0.31 [104.3] -490.5  8755.9 (3486)
#  4 FUVB      61.2 (707.9)    -386.4 0.84 [104.1] -490.5  8821.2 (3486)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
# Warning:  SPWCSTAB = N/A, so WCS keywords will not be updated
# End   21-Apr-2021 15:18:10 EDT
# CALCOS version 3.3.10
# numpy version 1.19.2
# astropy version 4.2.1
# Begin 21-Apr-2021 15:18:10 EDT
# Input file = leih01f6q_rawtag_a.fits
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih01f6q_rawtag_a.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih01f6q_rawtag_b.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
#
# TIME-TAG calibration -- 21-Apr-2021 15:18:11 EDT
# Input     leih01f6q_rawtag_a.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01f6q_corrtag_a.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01f6q_flt_a.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01f6q_counts_a.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01f6q_lampflash_a.fits
# DETECTOR  FUV, segment A
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1291, FPOFFSET 0
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.7  30.7  30.0  16.0
# 2:  60.5  90.5  30.0  75.5
# 3:  120.7  150.7  30.0  136.3
# 4:  180.7  210.0  29.4  195.5
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVA      59.3 (651.1)      63.9 0.94 [ 63.9]    0.0  9663.2 (3929)
#  2 FUVA      59.4 (651.2)      63.3 0.67 [ 63.3]    0.0  9908.6 (3936)
#  3 FUVA      59.4 (651.3)      63.4 0.47 [ 63.4]    0.0  9863.2 (3951)
#  4 FUVA      59.4 (651.3)      63.4 0.67 [ 63.4]    0.0  9515.8 (3976)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
#
# TIME-TAG calibration -- 21-Apr-2021 15:18:31 EDT
# Input     leih01f6q_rawtag_b.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01f6q_corrtag_b.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01f6q_flt_b.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01f6q_counts_b.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01f6q_lampflash_b.fits
# DETECTOR  FUV, segment B
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1291, FPOFFSET 0
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.5  30.5  30.0  15.9
# 2:  60.5  90.5  30.0  75.4
# 3:  120.5  150.5  30.0  135.6
# 4:  180.5  210.0  29.5  195.6
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVB      61.1 (709.4)      59.0 1.56 [ 59.0]    0.0  5770.9 (2533)
#  2 FUVB      61.2 (709.5)      58.7 1.49 [ 58.7]    0.0  5408.4 (2539)
#  3 FUVB      61.3 (709.6)      58.1 1.66 [ 58.1]    0.0  5348.9 (2551)
#  4 FUVB      61.3 (709.5)      58.4 0.79 [ 58.4]    0.0  5510.9 (2552)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
# Warning:  SPWCSTAB = N/A, so WCS keywords will not be updated
# End   21-Apr-2021 15:18:52 EDT
# CALCOS version 3.3.10
# numpy version 1.19.2
# astropy version 4.2.1
# Begin 21-Apr-2021 15:18:52 EDT
# Input file = leih02c8q_rawtag_a.fits
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih02c8q_rawtag_a.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih02c8q_rawtag_b.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
#
# TIME-TAG calibration -- 21-Apr-2021 15:18:53 EDT
# Input     leih02c8q_rawtag_a.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c8q_corrtag_a.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c8q_flt_a.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c8q_counts_a.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c8q_lampflash_a.fits
# DETECTOR  FUV, segment A
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1327, FPOFFSET -2
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.7  30.5  29.8  15.9
# 2:  60.7  90.5  29.8  75.3
# 3:  120.7  150.7  30.0  135.7
# 4:  180.7  210.0  29.4  195.7
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVA      59.3 (648.7)    -427.1 0.63 [ 43.7] -470.8  8753.9 (4109)
#  2 FUVA      59.4 (648.8)    -427.4 1.14 [ 43.4] -470.8  8597.5 (4085)
#  3 FUVA      59.3 (648.7)    -427.6 0.73 [ 43.2] -470.8  8476.9 (4112)
#  4 FUVA      59.4 (648.9)    -427.7 0.54 [ 43.0] -470.8  8861.4 (4053)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
#
# TIME-TAG calibration -- 21-Apr-2021 15:19:13 EDT
# Input     leih02c8q_rawtag_b.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c8q_corrtag_b.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c8q_flt_b.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c8q_counts_b.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih02c8q_lampflash_b.fits
# DETECTOR  FUV, segment B
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1327, FPOFFSET -2
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.7  30.5  29.8  16.0
# 2:  60.7  90.7  30.0  75.8
# 3:  120.7  150.5  29.8  136.0
# 4:  180.5  209.9  29.4  195.6
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVB      61.1 (707.2)    -430.6 0.72 [ 42.1] -472.7  7305.1 (3476)
#  2 FUVB      61.1 (707.2)    -431.1 0.41 [ 41.6] -472.7  7280.4 (3467)
#  3 FUVB      61.1 (707.2)    -431.1 0.75 [ 41.7] -472.7  7402.3 (3482)
#  4 FUVB      61.1 (707.2)    -431.2 0.53 [ 41.5] -472.7  7452.9 (3477)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
# Warning:  SPWCSTAB = N/A, so WCS keywords will not be updated
# End   21-Apr-2021 15:19:33 EDT
# CALCOS version 3.3.10
# numpy version 1.19.2
# astropy version 4.2.1
# Begin 21-Apr-2021 15:19:33 EDT
# Input file = leih03ioq_rawtag_a.fits
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih03ioq_rawtag_a.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
#
# TIME-TAG calibration -- 21-Apr-2021 15:19:34 EDT
# Input     leih03ioq_rawtag_a.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih03ioq_corrtag_a.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih03ioq_flt_a.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih03ioq_counts_a.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih03ioq_lampflash_a.fits
# DETECTOR  FUV, segment A
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G140L, CENWAVE 800, FPOFFSET 0
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$52j2110ml_lamp.fits
# XTRACTAB= lref$52j2110kl_1dx.fits
# DISPTAB = lref$52j2117ml_disp.fits
# lamp on, off, duration, median time:
# 1:  0.8  30.8  30.0  16.1
# 2:  60.8  90.8  30.0  76.0
# 3:  121.8  150.6  28.8  136.4
# 4:  180.8  210.8  30.0  195.7
# 5:  241.8  270.8  29.0  256.5
# 6:  300.8  330.8  30.0  316.0
# 7:  360.8  390.8  30.0  375.6
# 8:  420.8  450.0  29.2  435.4
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVA       0.5 (564.8)       0.0 0.00 [  0.0]    0.0     0.0 (0)  # not found
#  2 FUVA       0.5 (564.8)       0.0 4.57 [256.8]    0.0  19850229.5 (6127)  # not found
#  3 FUVA       0.6 (564.9)       0.0 0.00 [  0.0]    0.0     0.0 (0)  # not found
#  4 FUVA       0.5 (564.8)       0.0 0.00 [  0.0]    0.0     0.0 (0)  # not found
#  5 FUVA       0.6 (564.9)       0.0 0.00 [  0.0]    0.0     0.0 (0)  # not found
#  6 FUVA       0.6 (564.9)       0.0 0.00 [  0.0]    0.0     0.0 (0)  # not found
#  7 FUVA       0.6 (564.9)       0.0 0.00 [  0.0]    0.0     0.0 (0)  # not found
#  8 FUVA       0.5 (564.8)       0.0 0.00 [  0.0]    0.0     0.0 (0)  # not found
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
# Warning:  SPWCSTAB = N/A, so WCS keywords will not be updated
# End   21-Apr-2021 15:20:03 EDT
# CALCOS version 3.3.10
# numpy version 1.19.2
# astropy version 4.2.1
# Begin 21-Apr-2021 15:20:03 EDT
# Input file = leih03imq_rawtag_a.fits
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih03imq_rawtag_a.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
#
# TIME-TAG calibration -- 21-Apr-2021 15:20:04 EDT
# Input     leih03imq_rawtag_a.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih03imq_corrtag_a.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih03imq_flt_a.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih03imq_counts_a.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih03imq_lampflash_a.fits
# DETECTOR  FUV, segment A
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G140L, CENWAVE 800, FPOFFSET -1
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$52j2110ml_lamp.fits
# XTRACTAB= lref$52j2110kl_1dx.fits
# DISPTAB = lref$52j2117ml_disp.fits
# lamp on, off, duration, median time:
# 1:  0.7  30.7  30.0  16.0
# 2:  60.7  90.7  30.0  75.8
# 3:  121.7  150.7  29.0  136.3
# 4:  180.7  210.7  30.0  195.7
# 5:  241.7  270.7  29.0  256.1
# 6:  300.7  330.7  30.0  315.6
# 7:  360.7  390.7  30.0  375.8
# 8:  420.7  450.0  29.3  435.4
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVA       0.5 (564.8)    -255.2 0.00 [  0.0] -255.2     0.0 (0)  # not found
#  2 FUVA       0.5 (564.8)    -255.2 0.00 [  0.0] -255.2     0.0 (0)  # not found
#  3 FUVA       0.5 (564.8)    -255.2 0.00 [  0.0] -255.2     0.0 (0)  # not found
#  4 FUVA       0.6 (564.9)    -255.2 0.00 [  0.0] -255.2     0.0 (0)  # not found
#  5 FUVA       0.6 (564.9)    -255.2 0.00 [  0.0] -255.2     0.0 (0)  # not found
#  6 FUVA       0.6 (564.9)    -255.2 0.00 [  0.0] -255.2     0.0 (0)  # not found
#  7 FUVA       0.6 (564.9)    -255.2 0.00 [  0.0] -255.2     0.0 (0)  # not found
#  8 FUVA       0.7 (565.0)    -255.2 0.00 [  0.0] -255.2     0.0 (0)  # not found
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
# Warning:  SPWCSTAB = N/A, so WCS keywords will not be updated
# End   21-Apr-2021 15:20:30 EDT
# CALCOS version 3.3.10
# numpy version 1.19.2
# astropy version 4.2.1
# Begin 21-Apr-2021 15:20:30 EDT
# Input file = leih03ibq_rawtag_a.fits
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih03ibq_rawtag_a.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
#
# TIME-TAG calibration -- 21-Apr-2021 15:20:31 EDT
# Input     leih03ibq_rawtag_a.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih03ibq_corrtag_a.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih03ibq_flt_a.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih03ibq_counts_a.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih03ibq_lampflash_a.fits
# DETECTOR  FUV, segment A
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G140L, CENWAVE 800, FPOFFSET 0
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$52j2110ml_lamp.fits
# XTRACTAB= lref$52j2110kl_1dx.fits
# DISPTAB = lref$52j2117ml_disp.fits
# lamp on, off, duration, median time:
# 1:  0.7  30.7  30.0  15.9
# 2:  121.7  150.7  29.0  136.6
# 3:  241.7  270.7  29.0  256.2
# 4:  361.7  390.7  29.0  376.5
# 5:  481.7  510.7  29.0  496.1
# 6:  601.7  630.7  29.0  616.4
# 7:  721.7  750.7  29.0  736.3
# 8:  841.7  870.7  29.0  856.1
# 9:  961.7  990.7  29.0  976.0
# 10:  1081.7  1110.7  29.0  1096.4
# 11:  1201.7  1230.7  29.0  1216.2
# 12:  1321.7  1350.7  29.0  1336.2
# 13:  1441.7  1470.7  29.0  1456.4
# 14:  1561.7  1590.7  29.0  1576.4
# 15:  1681.7  1710.7  29.0  1696.2
# ...
# 3:  120.7  150.5  29.8  135.5
# 4:  180.7  210.0  29.4  195.6
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVB      61.3 (708.2)     370.8 1.09 [126.8]  244.1  6937.4 (3003)
#  2 FUVB      61.3 (708.2)     370.9 1.29 [126.8]  244.1  6395.1 (2949)
#  3 FUVB      61.3 (708.2)     370.7 1.01 [126.6]  244.1  6566.9 (2926)
#  4 FUVB      61.3 (708.2)     370.6 0.73 [126.6]  244.1  6346.2 (2909)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
# Warning:  SPWCSTAB = N/A, so WCS keywords will not be updated
# End   21-Apr-2021 15:30:14 EDT
# CALCOS version 3.3.10
# numpy version 1.19.2
# astropy version 4.2.1
# Begin 21-Apr-2021 15:30:14 EDT
# Input file = leih01fbq_rawtag_a.fits
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih01fbq_rawtag_a.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih01fbq_rawtag_b.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
#
# TIME-TAG calibration -- 21-Apr-2021 15:30:15 EDT
# Input     leih01fbq_rawtag_a.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01fbq_corrtag_a.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01fbq_flt_a.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01fbq_counts_a.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01fbq_lampflash_a.fits
# DETECTOR  FUV, segment A
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1291, FPOFFSET 1
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.7  30.7  30.0  15.4
# 2:  60.7  90.5  29.8  75.7
# 3:  120.7  150.5  29.8  135.7
# 4:  180.7  210.0  29.3  195.2
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVA      59.1 (651.0)     449.9 0.88 [212.1]  237.7  7840.9 (3694)
#  2 FUVA      59.3 (651.2)     449.6 0.44 [211.9]  237.7  7633.5 (3683)
#  3 FUVA      59.4 (651.3)     449.6 1.09 [211.9]  237.7  7675.2 (3731)
#  4 FUVA      59.4 (651.3)     449.7 0.50 [212.0]  237.7  7676.8 (3677)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
#
# TIME-TAG calibration -- 21-Apr-2021 15:30:34 EDT
# Input     leih01fbq_rawtag_b.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01fbq_corrtag_b.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01fbq_flt_b.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01fbq_counts_b.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01fbq_lampflash_b.fits
# DETECTOR  FUV, segment B
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1291, FPOFFSET 1
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.5  30.3  29.8  15.7
# 2:  60.5  90.5  30.0  75.5
# 3:  120.5  150.5  30.0  136.0
# 4:  180.5  209.9  29.4  195.0
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVB      61.4 (709.7)     443.6 1.25 [216.0]  227.6  4807.9 (2425)
#  2 FUVB      61.4 (709.6)     443.6 1.55 [216.0]  227.6  4639.1 (2429)
#  3 FUVB      61.4 (709.7)     443.6 1.54 [216.0]  227.6  4823.7 (2417)
#  4 FUVB      61.4 (709.6)     443.4 1.66 [215.8]  227.6  4760.9 (2439)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
# Warning:  SPWCSTAB = N/A, so WCS keywords will not be updated
# End   21-Apr-2021 15:30:55 EDT
# CALCOS version 3.3.10
# numpy version 1.19.2
# astropy version 4.2.1
# Begin 21-Apr-2021 15:30:55 EDT
# Input file = leih01ezq_rawtag_a.fits
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih01ezq_rawtag_a.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih01ezq_rawtag_b.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
#
# TIME-TAG calibration -- 21-Apr-2021 15:30:56 EDT
# Input     leih01ezq_rawtag_a.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01ezq_corrtag_a.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01ezq_flt_a.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01ezq_counts_a.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01ezq_lampflash_a.fits
# DETECTOR  FUV, segment A
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1291, FPOFFSET -1
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.7  30.7  30.0  15.4
# 2:  60.7  90.7  30.0  75.5
# 3:  120.7  150.7  30.0  136.1
# 4:  180.7  210.0  29.4  195.4
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVA      59.2 (651.1)     -45.1 1.70 [189.5] -234.6  10802.5 (3940)
#  2 FUVA      59.4 (651.3)     -45.2 0.95 [189.4] -234.6  10562.9 (3962)
#  3 FUVA      59.5 (651.3)     -45.0 0.38 [189.7] -234.6  10671.6 (3962)
#  4 FUVA      59.3 (651.2)     -44.9 1.86 [189.7] -234.6  11005.5 (3974)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
#
# TIME-TAG calibration -- 21-Apr-2021 15:31:14 EDT
# Input     leih01ezq_rawtag_b.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01ezq_corrtag_b.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01ezq_flt_b.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01ezq_counts_b.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01ezq_lampflash_b.fits
# DETECTOR  FUV, segment B
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1291, FPOFFSET -1
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.6  30.4  29.8  15.3
# 2:  60.6  90.6  30.0  75.8
# 3:  120.6  150.6  30.0  135.1
# 4:  180.6  210.0  29.4  195.1
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVB      61.2 (709.5)     -50.5 4.16 [185.7] -236.2  5617.4 (2470)
#  2 FUVB      61.1 (709.4)     -50.7 0.99 [185.5] -236.2  5067.2 (2462)
#  3 FUVB      61.3 (709.6)     -50.1 5.67 [186.1] -236.2  5281.2 (2526)
#  4 FUVB      61.4 (709.6)     -50.4 1.67 [185.8] -236.2  4925.4 (2470)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
# Warning:  SPWCSTAB = N/A, so WCS keywords will not be updated
# End   21-Apr-2021 15:31:36 EDT
# CALCOS version 3.3.10
# numpy version 1.19.2
# astropy version 4.2.1
# Begin 21-Apr-2021 15:31:36 EDT
# Input file = leih01gaq_rawtag_a.fits
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih01gaq_rawtag_a.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
# Info:  aperture plate is offset by 65.08 pixels
# Warning:  EXPTYPE = WAVECAL but TAGFLASH != NONE for leih01gaq_rawtag_b.fits;
#     EXPTYPE will be changed to EXTERNAL/CAL.
#
# TIME-TAG calibration -- 21-Apr-2021 15:31:37 EDT
# Input     leih01gaq_rawtag_a.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01gaq_corrtag_a.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01gaq_flt_a.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01gaq_counts_a.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01gaq_lampflash_a.fits
# DETECTOR  FUV, segment A
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1309, FPOFFSET -2
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.6  30.6  30.0  15.7
# 2:  60.6  90.4  29.8  75.9
# 3:  120.6  150.6  30.0  135.7
# 4:  180.6  210.0  29.4  195.0
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVA      59.6 (649.9)    -433.8 0.34 [ 61.3] -495.1  8167.5 (4004)
#  2 FUVA      59.6 (649.9)    -433.9 0.49 [ 61.2] -495.1  8172.8 (3996)
#  3 FUVA      59.7 (650.0)    -434.3 0.77 [ 60.8] -495.1  8395.9 (4011)
#  4 FUVA      59.8 (650.1)    -434.4 0.81 [ 60.7] -495.1  8599.7 (4004)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
#
# TIME-TAG calibration -- 21-Apr-2021 15:31:57 EDT
# Input     leih01gaq_rawtag_b.fits
# OutTag    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01gaq_corrtag_b.fits
# OutFlt    /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01gaq_flt_b.fits
# OutCounts /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01gaq_counts_b.fits
# OutFlash  /Users/ahirschauer/Documents/Year4/04-2021/Lamp_Tabs/ahirscha58916/output/leih01gaq_lampflash_b.fits
# DETECTOR  FUV, segment B
# EXPTYPE   EXTERNAL/CAL
# OPT_ELEM  G130M, CENWAVE 1309, FPOFFSET -2
# APERTURE  WCA
#
# BADTCORR  OMIT
# RANDCORR  PERFORM
# RANDSEED = 123456789
# TEMPCORR  PERFORM
# BRFTAB  = lref$x1u1459il_brf.fits
# GEOCORR   PERFORM
# GEOFILE = lref$x1u1459gl_geo.fits
# IGEOCORR  PERFORM
# DGEOCORR  OMIT
# XWLKCORR  PERFORM
# XWLKFILE= lref$14o2013ql_xwalk.fits
# YWLKCORR  PERFORM
# YWLKFILE= lref$14o2013rl_ywalk.fits
# DEADCORR  PERFORM
# DEADTAB = lref$s7g1700gl_dead.fits
# PHACORR   PERFORM
# PHATAB  = lref$wc318317l_pha.fits
# DOPPCORR  OMIT
# FLATCORR  OMIT
# WAVECORR  PERFORM
# Process tagflash wavecal
# WCPTAB  = lref$u1t1616ql_wcp.fits
# LAMPTAB = lref$23n1744jl_lamp.fits
# XTRACTAB= lref$x1v17414l_1dx.fits
# DISPTAB = lref$xaa18189l_disp.fits
# lamp on, off, duration, median time:
# 1:  0.6  30.6  30.0  16.0
# 2:  60.6  90.6  30.0  75.6
# 3:  120.6  150.6  30.0  135.4
# 4:  180.6  210.0  29.4  195.7
#   segment    cross-disp           dispersion direction
#             shift (locn)      shift err  [orig.]    FP   chi sq (n)
#   -------   -------------     -------------------------  ----------
#  1 FUVB      61.7 (708.6)    -433.3 1.02 [ 59.3] -492.7  7157.9 (3186)
#  2 FUVB      61.8 (708.6)    -433.4 0.53 [ 59.2] -492.7  6953.6 (3162)
#  3 FUVB      61.8 (708.7)    -433.9 0.86 [ 58.7] -492.7  7148.8 (3174)
#  4 FUVB      61.6 (708.4)    -434.1 0.78 [ 58.6] -492.7  7106.8 (3194)
# LAMPUSED = NONE, which is incorrect; the value will be reset to P1.
# HELCORR   OMIT for computing wavelengths for the corrtag table
# BRSTCORR  OMIT
# TRCECORR  OMIT
# ALGNCORR  OMIT
# DQICORR   PERFORM
# BPIXTAB = lref$36d1836ml_bpix.fits
# GSAGTAB = lref$54c1542dl_gsag.fits
# SPOTTAB = lref$zas1615jl_spot.fits
# STATFLAG  T
# Append a TIMELINE extension.
# X1DCORR   OMIT
# Warning:  SPWCSTAB = N/A, so WCS keywords will not be updated
# End   21-Apr-2021 15:32:17 EDT

# %%
# let's take a look at one of the lampflash files

# here I'm selecting one from my output directory totally at random
# whoops that was a lot, let's change this...

data = fits.getdata('leih01gaq_lampflash.fits')

# %%
# what are all the column names in the lampflash file?

data.columns
# Out:
# ColDefs(
#     name = 'SEGMENT'; format = '4A'
#     name = 'TIME'; format = '1D'; unit = 's'; disp = 'F8.3'
#     name = 'EXPTIME'; format = '1D'; unit = 's'; disp = 'F8.3'
#     name = 'LAMP_ON'; format = '1D'; unit = 's'; disp = 'F8.3'
#     name = 'LAMP_OFF'; format = '1D'; unit = 's'; disp = 'F8.3'
#     name = 'NELEM'; format = '1J'; disp = 'I6'
#     name = 'WAVELENGTH'; format = '16384D'; unit = 'angstrom'
#     name = 'NET'; format = '16384E'; unit = 'count /s'
#     name = 'GROSS'; format = '16384E'; unit = 'count /s'
#     name = 'BACKGROUND'; format = '16384E'; unit = 'count /s'
#     name = 'SHIFT_DISP'; format = '1E'; unit = 'pixel'
#     name = 'SHIFT_XDISP'; format = '1E'; unit = 'pixel'
#     name = 'SPEC_FOUND'; format = '1L'
#     name = 'CHI_SQUARE'; format = '1E'
#     name = 'N_DEG_FREEDOM'; format = '1J'; disp = 'I5'
# )

# %%
# show me the data from the SHIFT_DISP column

data['SHIFT_DISP']

# we see eight output values, each corresponding to one lamp flash from
# what must be one of the G140L/800 observations, from one of the FP-POS
# Out:
# array([-433.7379 , -433.9637 , -434.30478, -434.42685, -433.29044,
#        -433.46817, -433.9612 , -434.0909 ], dtype=float32)

# %%
# now we check the existing Lamp Tab here:
# https://hst-crds.stsci.edu/
# and we go to COS, then lamptab, finding the current one for LP4, which is
# https://hst-crds.stsci.edu/browse/2bj2256ol_lamp.fits

# we need to get rid of the fp pixel shift values that we're seeing
# since we don't have those yet for LP5, we're using LP4 as a guess
# since they probably don't change very much for each LP

# NB LP4 has what we need for G140L/800, which we're doing now
# also note that LP5 is close to LP2, but there is no lamptab for LP2
# (it uses the lamptab file for LP1)

# this won't be perfect, but we'll be pretty close

# okay, now we have to *get* the file, which you can't download from the website

# $lref is our COS reference file folder, which is located at:
# /grp/hst/cdbs/lref/

# (you can CD into this directory if you're on the VPN, then CP to wherever)

# now open the LampTab, open the row for cenwave 800, and locate the FP pixel shift
# for all for FP-POS
# (we're interested in cenwave 800 since our randomly-selected file is that)

lampdata4 = fits.getdata('LP4_LampTab.fits')

# %%
# what columns are in the new variable "lampdata"?

lampdata4.columns
# Out:
# ColDefs(
#     name = 'SEGMENT'; format = '4A'; disp = 'A4'
#     name = 'OPT_ELEM'; format = '5A'; disp = 'A8'
#     name = 'CENWAVE'; format = 'J'; unit = 'angstrom'; disp = 'I5'
#     name = 'FPOFFSET'; format = 'J'; unit = 'steps'; disp = 'I5'
#     name = 'HAS_LINES'; format = 'L'; disp = 'L1'
#     name = 'FP_PIXEL_SHIFT'; format = 'D'; disp = 'G15.7'
#     name = 'INTENSITY'; format = '16384D'
# )

# %%
# we are selecting (using numpy) from files of G140L and 800

sel4 = np.where((lampdata4['OPT_ELEM'] == 'G140L') & (lampdata4['CENWAVE'] == 800))

# and now selecting the lampdata from what we defined as "sel", both the FP offset
# and the fp pixel shift (not sure of the formatting yet though)

lampdata4[sel4]['FPOFFSET'], lampdata4[sel4]['FP_PIXEL_SHIFT']

# hmm, it looks like the FP-POS = 1 FP_PIXEL_SHIFT is off by ~50 pixels
# compared to what we saw earlier...
# Out:
# (array([-2, -1,  0,  1], dtype=int32),
#  array([-485.11078455, -214.06629603,    0.        ,  277.24091168]))

# %%
# let's take a look at the LP3 lamptab file...

lampdata3 = fits.getdata('LP3_LampTab.fits')

# %%
lampdata3.columns
# Out:
# ColDefs(
#     name = 'SEGMENT'; format = '4A'; disp = 'A4'
#     name = 'OPT_ELEM'; format = '5A'; disp = 'A8'
#     name = 'CENWAVE'; format = 'J'; unit = 'angstrom'; disp = 'I5'
#     name = 'FPOFFSET'; format = 'J'; unit = 'steps'; disp = 'I5'
#     name = 'HAS_LINES'; format = 'L'; disp = 'L1'
#     name = 'FP_PIXEL_SHIFT'; format = 'D'; disp = 'G15.7'
#     name = 'INTENSITY'; format = '16384D'
# )

# %%
sel3 = np.where((lampdata3['OPT_ELEM'] == 'G140L') & (lampdata3['CENWAVE'] == 1105))

lampdata3[sel3]['FPOFFSET'], lampdata3[sel3]['FP_PIXEL_SHIFT']
# Out:
# (array([-2, -1,  0,  1], dtype=int32),
#  array([-517.44628131, -255.17912466,    0.        ,  235.57090234]))

# %%
# okay so we checked where the FP pixel shift would be expected at LP3
# but for G140L/1105 (since cenwave 800 doesn't exist here yet)
# and we found that the "expected" shift is even more different!

# let's now take a look at one of the _lampflash.fits files for G130M
# from my program's dataset and compare that to the LP4 lampflash file

data2 = fits.getdata('leih01f6q_lampflash.fits')

# this one is a G130M lampflash file

# %%
data2.columns
# Out:
# ColDefs(
#     name = 'SEGMENT'; format = '4A'
#     name = 'TIME'; format = '1D'; unit = 's'; disp = 'F8.3'
#     name = 'EXPTIME'; format = '1D'; unit = 's'; disp = 'F8.3'
#     name = 'LAMP_ON'; format = '1D'; unit = 's'; disp = 'F8.3'
#     name = 'LAMP_OFF'; format = '1D'; unit = 's'; disp = 'F8.3'
#     name = 'NELEM'; format = '1J'; disp = 'I6'
#     name = 'WAVELENGTH'; format = '16384D'; unit = 'angstrom'
#     name = 'NET'; format = '16384E'; unit = 'count /s'
#     name = 'GROSS'; format = '16384E'; unit = 'count /s'
#     name = 'BACKGROUND'; format = '16384E'; unit = 'count /s'
#     name = 'SHIFT_DISP'; format = '1E'; unit = 'pixel'
#     name = 'SHIFT_XDISP'; format = '1E'; unit = 'pixel'
#     name = 'SPEC_FOUND'; format = '1L'
#     name = 'CHI_SQUARE'; format = '1E'
#     name = 'N_DEG_FREEDOM'; format = '1J'; disp = 'I5'
# )

# %%
data2['SHIFT_DISP']
# Out:
# array([63.877857, 63.45603 , 63.402016, 63.481426, 58.947098, 58.388226,
#        58.38295 , 58.561092], dtype=float32)

# %%
data2['SEGMENT']
# Out:
# chararray(['FUVA', 'FUVA', 'FUVA', 'FUVA', 'FUVB', 'FUVB', 'FUVB', 'FUVB'],
#           dtype='<U4')

# %%
# we wanted to figure out which cenwave we're looking at (it's 1291)

#fits.getheader('leih01f6q_lampflash.fits')

# %%
# what we're seeing is that there are four flashes, but now two segments,
# whereas with G140L there were eight flashes on one segment.
# what a coincidence!

# let's compare these to the LP4 lamp flash file

sel2 = np.where((lampdata4['OPT_ELEM'] == 'G130M') & (lampdata4['CENWAVE'] == 1291) & (lampdata4['SEGMENT'] == 'FUVA'))

lampdata4[sel2]['FPOFFSET'], lampdata4[sel2]['FP_PIXEL_SHIFT']
# Out:
# (array([-2, -1,  0,  1], dtype=int32),
#  array([-519.2847117 , -197.7793916 ,    0.        ,  291.77080735]))

# %%
# the numbers we're seeing for the pixel shift aren't similar to what we see in the
# older LampTab files, but keep in mind that the data we're seeing for this program
# is probing parameter space that hasn't been looked at before, so it shouldn't be a
# surprise if the pixel offsets are different compared to other LPs.

# we're going to be comparing the pixel shifts relative to each other, not compared to
# the other (older) LPs, so whatever values we get is what we get, end of story!

# maybe this is why they made the placeholder LampTab files now?
