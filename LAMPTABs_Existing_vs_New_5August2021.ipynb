# %%
# 1

########### 5 August 2021 ##########
######### Alec Hirschauer ##########
#
# In this notebook, we will be testing the LAMPTAB files
# existing vs. new
# by comparing their INTENSITY values.
#
# new LP3 file = 30July2021_G140L_LP3_lamp.fits
# new LP5 file = 30July2021_G130M_LP5_lamp.fits
# 
# existing LP3 file = 52j2110ml_lamp.fits
# existing LP4 file = 2bj2256ol_lamp.fits

# %%
# 2

# First thing needed is to import the relevant Python libraries:

import numpy as np
#import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
import calcos
from astropy.io import fits
import glob

# I'm not actually sure how many of these are really relevant,
# but they're what I've used in the past, so I'll keep them now
# just in case.
#
# I'd rather have 'em and not need 'em than want 'em but not have 'em.
#
# UPDATE: The astroconda version of Jupyter doesn't like pandas,
# so I've commented that out.

# UPDATE: Nat Kerman's COS-Notebooks are a great guide for doing
# plotting of COS data, so I'm going to use this as a major reference
# for me, which includes copy+pasting the cell he uses to
# demonstrate what Python packages are necessary.
#
# A bunch will be duplicates, but I don't think that matters.

# This line causes matplotlib plots to appear in the Notebook 
# instead of possibly showing up in separate windows
# %matplotlib inline

# Import for: Manipulating arrays
import numpy as np

# Import for: Managing system variables and paths
import sys 
import os
from pathlib import Path

# Imports for: Reading in data
from astropy.io import fits
from astropy.table import Table

# Import for: Plotting
import matplotlib.pyplot as plt

# Imports for: Dealing with units and plotting them
from astropy import units as u
from astropy.visualization import quantity_support
quantity_support()

# Imports for: Downloading data from archive
from astroquery.mast import Mast
from astroquery.mast import Observations
from astroquery.mast import Catalogs

# %%
# 3

# Nat also includes a cell which suppresses warning text:

# Our arrays will encounter divide by 0 warnings, which is OK here, 
# but we want to suppress the warning text with the next code line.
   # DO NOT COPY the next line into your own code without careful consideration
    
np.warnings.filterwarnings('ignore')

# %%
# 4

# Second thing needed is to specify which files will be
# referenced once I start the testing.
#
# I alluded to these in the first Cell, but I'll be more
# explicit about them here.

new_lamp_name_G140L_LP3 = '30July2021_G140L_LP3_lamp.fits'
new_lamp_name_G130M_LP5 = '30July2021_G130M_LP5_lamp.fits'

existing_lamp_LP3 = '52j2110ml_lamp.fits'
existing_lamp_LP4 = '2bj2256ol_lamp.fits'

# %%
# 5

# As for actually plotting the COS data, I am turning to the
# COS-Notebooks reference tutorials put together by Nat Kerman
# to guide me.
#
# I've already copy+pasted some information from the "ViewData"
# COS-Notebook.
#
# To start, I'm simply going to make a line plot from the single
# segment of FUVA (without its error) for G140L/c800,
# since this doesn't have an FUVB segment anyway.
#
# First, I'll need to learn something about the files themselves

new_lamp_LP3_data = Table.read('30July2021_G140L_LP3_lamp.fits')
columns_new_lamp_LP3 = new_lamp_LP3_data.colnames
print("\n\nTable of new LP3 FUV data with columns:\n",columns_new_lamp_LP3, "\n\n")

new_lamp_LP5_data = Table.read('30July2021_G130M_LP5_lamp.fits')
columns_new_lamp_LP5 = new_lamp_LP5_data.colnames
print("\n\nTable of new LP5 FUV data with columns:\n",columns_new_lamp_LP3, "\n\n")

existing_lamp_LP3_data = Table.read('52j2110ml_lamp.fits')
columns_existing_lamp_LP3 = existing_lamp_LP3_data.columns
print("\n\nTable of existing LP3 FUV data with columns:\n",columns_existing_lamp_LP3, "\n\n")

existing_lamp_LP4_data = Table.read('2bj2256ol_lamp.fits')
columns_existing_lamp_LP4 = existing_lamp_LP4_data.columns
print("\n\nTable of existing LP4 FUV data with columns:\n",columns_existing_lamp_LP4, "\n\n")
# Out:
# Table of new LP3 FUV data with columns:
#  ['SEGMENT', 'OPT_ELEM', 'CENWAVE', 'FPOFFSET', 'HAS_LINES', 'FP_PIXEL_SHIFT', 'INTENSITY']
#
#
#
#
# Table of new LP5 FUV data with columns:
#  ['SEGMENT', 'OPT_ELEM', 'CENWAVE', 'FPOFFSET', 'HAS_LINES', 'FP_PIXEL_SHIFT', 'INTENSITY']
#
#
#
#
# Table of existing LP3 FUV data with columns:
#  <TableColumns names=('SEGMENT','OPT_ELEM','CENWAVE','FPOFFSET','HAS_LINES','FP_PIXEL_SHIFT','INTENSITY')>
#
#
#
#
# Table of existing LP4 FUV data with columns:
#  <TableColumns names=('SEGMENT','OPT_ELEM','CENWAVE','FPOFFSET','HAS_LINES','FP_PIXEL_SHIFT','INTENSITY')>

# %%
# 6

# Now that I have recovered the 'INTENSITY' columns from both the
# new LP3 LAMPTAB file (for G140L/c800) and the old LP4 LAMPTAB file,
# I can try plotting these against each other to see if they
# line up in a relatively one-to-one fashion.

# UPDATE: Elaine showed me that what I had were incorrect;
# the [0] index points to the wrong data, and supplied
# a more correct set of definitions.

selnew = np.where((new_lamp_LP3_data['CENWAVE'] == 800) &
               (new_lamp_LP3_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP3_data['FPOFFSET'] == -2))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 800) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == -2))

new_intensity = new_lamp_LP3_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c800 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c800 intensity from LP3 LAMPTAB")
  
ax.set_title("New vs. Existing G140L/c800 LAMPTAB Files (FP-POS=1; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")
 
plt.legend()
plt.grid(True)
plt.show()
plt.close()
#plt.savefig("G140L_c800_FPPOS1.png")

# %%
# 7

# Great!
#
# I have the G140l/c800 comparison of intensities between
# the old _lamp.fits file at LP4 and the new _lamp.fits
# file at LP3.
#
# These are both at FP-POS=1 (changed from FP-POS=3) so arguably
# I could do similar comparisons as the above for the other
# three FP-POS settings, though I wouldn't expect it to change.
#
# May as well do it to be comprehensive, then afterward I can
# move on to the G130M cenwaves (1291, 1300, 1309, 1318, and 1327),
# keeping in mind that they have both Segments A and B.
#
# Below, I'll do a new Cell for each of the three plots.

selnew = np.where((new_lamp_LP3_data['CENWAVE'] == 800) &
               (new_lamp_LP3_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP3_data['FPOFFSET'] == -1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 800) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == -1))

new_intensity = new_lamp_LP3_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c800 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c800 intensity from LP3 LAMPTAB")
  
ax.set_title("New vs. Existing G140L/c800 LAMPTAB Files (FP-POS=2; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")
  
plt.legend()
plt.grid(True)
plt.show()
plt.close()
#plt.savefig("G140L_c800_FPPOS2.png")

# %%
# 8

selnew = np.where((new_lamp_LP3_data['CENWAVE'] == 800) &
               (new_lamp_LP3_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP3_data['FPOFFSET'] == 0))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 800) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == 0))

new_intensity = new_lamp_LP3_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c800 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c800 intensity from LP3 LAMPTAB")
  
ax.set_title("New vs. Existing G140L/c800 LAMPTAB Files (FP-POS=3; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")
 
plt.legend()
plt.grid(True)
plt.show()
plt.close()
#plt.savefig("G140L_c800_FPPOS3.png")

# %%
# 9

selnew = np.where((new_lamp_LP3_data['CENWAVE'] == 800) &
               (new_lamp_LP3_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP3_data['FPOFFSET'] == 1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 800) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == 1))

new_intensity = new_lamp_LP3_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c800 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c800 intensity from LP3 LAMPTAB")

ax.set_title("New vs. Existing G140L/c800 LAMPTAB Files (FP-POS=4; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")
 
plt.legend()
plt.grid(True)
plt.show()
plt.close()
#plt.savefig("G140L_c800_FPPOS4.png")

# %%
# 10

# Now that we've done the comparisons for G140L/c800,
# let's take a look at the G130M cenwaves.
#
# There are five we're interested in (1921, 1300, 1309, 1318, and 1327),
# and each one has four FP-POS position settings, plus all have
# both the FUVA and FUVB segments.

# %%
# 11

# Now let's plot the first G130M cenwave (1291), FUVA:

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1291) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == -2))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1291) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == -2))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1291 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1291 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1291 LAMPTAB Files (FP-POS=1; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()
#plt.savefig("G130M_c1291_FPPOS1.png")

# %%
# 12

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1291) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == -1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1291) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == -1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1291 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1291 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1291 LAMPTAB Files (FP-POS=2; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")
  
plt.legend()
plt.grid(True)
plt.show()
plt.close()
#plt.savefig("G130M_c1291_FPPOS2.png")

# %%
# 13

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1291) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == 0))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1291) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == 0))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1291 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1291 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1291 LAMPTAB Files (FP-POS=3; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")
 
plt.legend()
plt.grid(True)
plt.show()
plt.close()
#plt.savefig("G130M_c1291_FPPOS3.png")

# %%
# 14

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1291) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == 1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1291) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == 1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1291 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1291 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1291 LAMPTAB Files (FP-POS=4; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")
 
plt.legend()
plt.grid(True)
plt.show()
plt.close()
#plt.savefig("G130M_c1291_FPPOS4.png")

# %%
# 15

# Let's do the same thing now, but with FUVB:

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1291) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == -2))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1291) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == -2))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1291 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1291 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1291 LAMPTAB Files (FP-POS=1; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")
 
plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 16

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1291) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == -1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1291) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == -1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1291 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1291 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1291 LAMPTAB Files (FP-POS=2; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")
 
plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 17

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1291) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == 0))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1291) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == 0))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1291 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1291 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1291 LAMPTAB Files (FP-POS=3; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")
  
plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 18

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1291) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == 1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1291) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == 1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1291 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1291 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1291 LAMPTAB Files (FP-POS=4; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")
  
plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 19

# We see the same overlapping problem with the FUVB,
# so it's not limited to FUVA.
#
# Let's try this all now with G130M/c1300:

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1300) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == -2))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1300) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == -2))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1300 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1300 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1300 LAMPTAB Files (FP-POS=1; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 20

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1300) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == -1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1300) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == -1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1300 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1300 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1300 LAMPTAB Files (FP-POS=2; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 21

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1300) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == 0))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1300) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == 0))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1300 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1300 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1300 LAMPTAB Files (FP-POS=3; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 22

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1300) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == 1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1300) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == 1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1300 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1300 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1300 LAMPTAB Files (FP-POS=4; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 23

# Now Segment B with G130M/c1300:

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1300) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == -2))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1300) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == -2))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1300 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1300 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1300 LAMPTAB Files (FP-POS=1; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 24

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1300) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == -1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1300) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == -1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1300 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1300 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1300 LAMPTAB Files (FP-POS=2; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 25

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1300) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == 0))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1300) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == 0))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1300 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1300 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1300 LAMPTAB Files (FP-POS=3; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 26

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1300) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == 1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1300) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == 1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1300 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1300 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1300 LAMPTAB Files (FP-POS=4; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 27

# On to the next cenwave, Segment A G130M/c1309:

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1309) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == -2))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1309) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == -2))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1309 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1309 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1309 LAMPTAB Files (FP-POS=1; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 28

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1309) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == -1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1309) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == -1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1309 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1309 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1309 LAMPTAB Files (FP-POS=2; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 29

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1309) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == 0))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1309) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == 0))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1309 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1309 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1309 LAMPTAB Files (FP-POS=3; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 30

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1309) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == 1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1309) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == 1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1309 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1309 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1309 LAMPTAB Files (FP-POS=4; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 31

# Now Segment B with G130M/c1309:

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1309) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == -2))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1309) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == -2))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1309 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1309 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1309 LAMPTAB Files (FP-POS=1; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 32

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1309) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == -1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1309) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == -1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1309 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1309 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1309 LAMPTAB Files (FP-POS=2; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 33

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1309) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == 0))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1309) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == 0))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1309 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1309 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1309 LAMPTAB Files (FP-POS=3; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 34

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1309) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == 1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1309) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == 1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1309 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1309 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1309 LAMPTAB Files (FP-POS=4; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 35

# On to the next cenwave, Segment A G130M/c1318:

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1318) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == -2))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1318) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == -2))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1318 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1318 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1318 LAMPTAB Files (FP-POS=1; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 36

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1318) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == -1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1318) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == -1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1318 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1318 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1318 LAMPTAB Files (FP-POS=2; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 37

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1318) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == 0))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1318) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == 0))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1318 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1318 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1318 LAMPTAB Files (FP-POS=3; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 38

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1318) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == 1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1318) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == 1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1318 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1318 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1318 LAMPTAB Files (FP-POS=4; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 39

# Now Segment B with G130M/c1318:

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1318) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == -2))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1318) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == -2))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1318 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1318 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1318 LAMPTAB Files (FP-POS=1; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 40

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1318) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == -1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1318) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == -1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1318 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1318 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1318 LAMPTAB Files (FP-POS=2; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 41

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1318) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == 0))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1318) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == 0))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1318 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1318 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1318 LAMPTAB Files (FP-POS=3; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 42

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1318) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == 1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1318) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == 1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1318 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1318 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1318 LAMPTAB Files (FP-POS=4; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 43

# Finally, the last next cenwave, Segment A G130M/c1327:

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1327) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == -2))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1327) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == -2))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1327 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1327 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1327 LAMPTAB Files (FP-POS=1; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 44

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1327) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == -1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1327) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == -1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1327 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1327 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1327 LAMPTAB Files (FP-POS=2; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 45

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1327) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == 0))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1327) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == 0))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1327 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1327 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1327 LAMPTAB Files (FP-POS=3; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 46

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1327) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVA') &
               (new_lamp_LP5_data['FPOFFSET'] == 1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1327) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVA') &
               (existing_lamp_LP4_data['FPOFFSET'] == 1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1327 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1327 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1327 LAMPTAB Files (FP-POS=4; FUVA)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 47

# Finishing with Segment B for G130M/c1327:

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1327) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == -2))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1327) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == -2))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1327 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1327 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1327 LAMPTAB Files (FP-POS=1; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 48

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1327) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == -1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1327) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == -1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1327 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1327 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1327 LAMPTAB Files (FP-POS=2; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 49

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1327) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == 0))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1327) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == 0))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1327 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1327 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1327 LAMPTAB Files (FP-POS=3; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %%
# 50

selnew = np.where((new_lamp_LP5_data['CENWAVE'] == 1327) &
               (new_lamp_LP5_data['SEGMENT'] == 'FUVB') &
               (new_lamp_LP5_data['FPOFFSET'] == 1))

selold = np.where((existing_lamp_LP4_data['CENWAVE'] == 1327) &
               (existing_lamp_LP4_data['SEGMENT'] == 'FUVB') &
               (existing_lamp_LP4_data['FPOFFSET'] == 1))

new_intensity = new_lamp_LP5_data[selnew[0][0]]["INTENSITY"]
old_intensity = existing_lamp_LP4_data[selold[0][0]]["INTENSITY"]

fig1, ax = plt.subplots(1,1,figsize=(6,6), dpi=100)
ax.plot(old_intensity, label="existing c1327 intensity from LP4 LAMPTAB")
ax.plot(new_intensity, label="new c1327 intensity from LP5 LAMPTAB")
  
ax.set_title("New vs. Existing G130M/c1327 LAMPTAB Files (FP-POS=4; FUVB)")
ax.set_xlabel("X Pixels")
ax.set_ylabel("INTENSITY")

plt.legend()
plt.grid(True)
plt.show()
plt.close()
